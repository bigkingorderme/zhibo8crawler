# %%
import requests
import numpy as np
from pandas import DataFrame,Series
import json

# %%
url='https://db.qiumibao.com/f/index/player?pid='
r=requests.get(url+'1')
s=Series(r.json())
#
for i in range(5480,10000):
    r=requests.get(url+str(i+1))
    if r.json():
        sp=Series(r.json())
        sp['read_card']=''
        data.loc[i]=sp.values
        print(i,'  ',data.loc[i]['name'])
# Out:
# 5481    吉奥甲德兹
# 5482    科佐夫
# 5483    卢森科
# 5484    奥斯塔佩科
# 5485    萨基夫
# 5486    库内夫
# 5487    B.舒斯特
# 5488    O.特卡琴科
# 5489    博格丹·萨纳夫斯基
# 5490    沙博尼耶
# 5491    哈比卜·迪亚洛
# 5492    比坦
# 5493    马伊
# 5494    纳冬戈
# 5495    加斯蒂恩
# 5496    马尼翁
# 5497    格鲁吉
# 5498    西蒙科
# 5499    拉比迪
# 5500    杰森·贝托米耶
# 5501    杰西.派
# 5502    奥特雷
# 5503    H.马格内蒂
# 5504    瓦伦汀·昂利
# 5505    迪亚洛
# 5506    法乌苏里耶
# 5507    雅各布
# 5508    沙尔多内
# 5509    贝洛
# 5510    伯纳尔
# 5511    科埃夫
# 5512    卡斯特莱托
# 5513    韦伯
# 5514    戴维·奇奇
# 5515    法布里
# 5516    莱昂
# 5517    拉宋涅尔
# 5518    利尤尔
# 5519    潘德夫
# 5520    加拉比诺夫
# 5521    帕拉迪诺
# 5522    佩莱格里
# 5523    拉帕杜拉
# 5525    奥梅翁加
# 5527    里戈尼
# 5528    里西
# 5529    布雷克
# 5530    贝尔托拉奇
# 5531    森图里昂
# 5532    拉佐维奇
# 5533    维罗索
# 5534    塔拉布特
# 5536    比拉斯基
# 5537    苏卡诺维奇
# 5538    罗塞蒂尼
# 5539    伊佐
# 5541    斯波利
# 5544    佩林
# 5545    拉曼纳
# 5548    阿尔多·卡卢卢
# 5549    图兹哈
# 5550    安德里亚西马
# 5551    罗比奈
# 5552    萨奥
# 5553    巴卡约科
# 5554    简·路易斯
# 5555    巴
# ...

# %%
r=requests.get(url+'42')
stest=Series(r.json())
stest[]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8712 entries, 0 to 9999
# Data columns (total 43 columns):
# id                      8712 non-null object
# league_id               8712 non-null object
# league                  8712 non-null object
# team_id                 8712 non-null object
# team_name               8712 non-null object
# national_team_id        8712 non-null object
# national_team           8712 non-null object
# name                    8712 non-null object
# name_en                 8712 non-null object
# short_name              8712 non-null object
# short_en                8712 non-null object
# number                  8712 non-null object
# position                8712 non-null object
# nationality             8712 non-null object
# age                     8712 non-null object
# height                  8712 non-null object
# weight                  8712 non-null object
# games_played            8712 non-null object
# ...

# %%
# important
data.to_csv('/Users/shenxibo/study/python/data tables/zhibo8 players/zhiboplayer_p1.csv', encoding='utf-8')

# %%
data
# Out:
#         id league_id league team_id                 team_name  \
# 5479  5480         0            342                      沃斯卡拉
# 5481  5482         0            342                      沃斯卡拉
# 5482  5483         0            342                      沃斯卡拉
# 5483  5484         0            342                      沃斯卡拉
# 5484  5485         0            342                      沃斯卡拉
# 5485  5486         0            342                      沃斯卡拉
# 5486  5487         0           1709                     希尼克体育
# 5487  5488         0            342                      沃斯卡拉
# 5488  5489         0            342                      沃斯卡拉
# 5489  5490         0            342                      沃斯卡拉
# 5490  5491         0            352                      布雷斯特
# 5491  5492         0            352                      布雷斯特
# 5492  5493         0            352                      布雷斯特
# 5493  5494         0            352                      布雷斯特
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 40
# Data columns (total 43 columns):
# id                      38 non-null object
# league_id               38 non-null object
# league                  38 non-null object
# team_id                 38 non-null object
# team_name               38 non-null object
# national_team_id        38 non-null object
# national_team           38 non-null object
# name                    38 non-null object
# name_en                 38 non-null object
# short_name              38 non-null object
# short_en                38 non-null object
# number                  38 non-null object
# position                38 non-null object
# nationality             38 non-null object
# age                     38 non-null object
# height                  38 non-null object
# weight                  38 non-null object
# games_played            38 non-null object
# playing_time            38 non-null object
# ...

# %%
import pandas as pd
data2=pd.read_csv('/Users/shenxibo/study/python/data tables/zhibo8 players/zhiboplayer_p2.csv')
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9229 entries, 0 to 9228
# Data columns (total 44 columns):
# Unnamed: 0              9229 non-null int64
# id                      9229 non-null int64
# league_id               9229 non-null int64
# league                  172 non-null object
# team_id                 9229 non-null int64
# team_name               9219 non-null object
# national_team_id        9229 non-null int64
# national_team           197 non-null object
# name                    9229 non-null object
# name_en                 9225 non-null object
# short_name              9226 non-null object
# short_en                2 non-null object
# number                  9229 non-null int64
# position                8026 non-null object
# nationality             9226 non-null object
# age                     9229 non-null int64
# height                  9229 non-null object
# weight                  9229 non-null object
# games_played            9229 non-null int64
# ...

# %%
data_all=pd.concat([data,data2])
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17941 entries, 0 to 9228
# Data columns (total 43 columns):
# id                      17941 non-null object
# league_id               17941 non-null object
# league                  8884 non-null object
# team_id                 17941 non-null object
# team_name               17931 non-null object
# national_team_id        17941 non-null object
# national_team           8909 non-null object
# name                    17941 non-null object
# name_en                 17937 non-null object
# short_name              17938 non-null object
# short_en                8714 non-null object
# number                  17941 non-null object
# position                16738 non-null object
# nationality             17938 non-null object
# age                     17941 non-null object
# height                  17941 non-null object
# weight                  17941 non-null object
# games_played            17941 non-null object
# ...

# %%
data.columns
# Out:
# Index(['id', 'league_id', 'league', 'team_id', 'team_name', 'national_team_id',
#        'national_team', 'name', 'name_en', 'short_name', 'short_en', 'number',
#        'position', 'nationality', 'age', 'height', 'weight', 'games_played',
#        'playing_time', 'goal', 'assist', 'yellow_card', 'red_card', 'value',
#        'birthday', 'habit_foot', 'join_time', 'contract_time', 'avatar',
#        'flag', 'create_type', 'create_time', 'update_time', 'injury_history',
#        'transfers', 'season_performace', 'honors', 'charaters', 'read_card',
#        'position_performace', 'single_match_records', 'vs_teams',
#        'jersey_numbers'],
#       dtype='object')

# %%
data2=data2.drop('Unnamed: 0',axis=1)

# %%
data2.columns
# Out:
# Index(['id', 'league_id', 'league', 'team_id', 'team_name', 'national_team_id',
#        'national_team', 'name', 'name_en', 'short_name', 'short_en', 'number',
#        'position', 'nationality', 'age', 'height', 'weight', 'games_played',
#        'playing_time', 'goal', 'assist', 'yellow_card', 'red_card', 'value',
#        'birthday', 'habit_foot', 'join_time', 'contract_time', 'avatar',
#        'flag', 'create_type', 'create_time', 'update_time', 'injury_history',
#        'transfers', 'season_performace', 'honors', 'charaters', 'read_card',
#        'position_performace', 'single_match_records', 'vs_teams',
#        'jersey_numbers'],
#       dtype='object')

# %%
data=data_all
data.sample(5)
# Out:
#          id league_id league team_id      team_name national_team_id  \
# 3401  13951         0    NaN    1310           古积大学                0
# 5520   5521         0            333  Spezia Calcio             3269
# 3266  13798         0    NaN    1308        维托鲁康斯坦萨                0
# 2845  13133         0    NaN    1263        萨格勒布火车头                0
# 4661  15427         0    NaN    1478           厄斯特什                0
#
#      national_team   name             name_en short_name      ...        \
# 3401           NaN    科瓦什       Lorant Kovacs        科瓦什      ...
# 5520          保加利亚  加拉比诺夫    Andrey Galabinov      加拉比诺夫      ...
# 3266           NaN   亚历马坦      Alexandru Mata       亚历马坦      ...
# 2845           NaN     卡莱            F. Karai         卡莱      ...
# 4661           NaN   比尔格松  Andreas Birgersson       比尔格松      ...
#
#                                          injury_history  \
# 3401                                                 []
# ...

# %%
data.to_csv('/Users/shenxibo/study/python/data tables/zhibo8 players/zhiboplayer_all_1.csv',index=False,encoding='utf-8')

# %%
data.index=data['id']

# %%
data[data.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, league_id, league, team_id, team_name, national_team_id, national_team, name, name_en, short_name, short_en, number, position, nationality, age, height, weight, games_played, playing_time, goal, assist, yellow_card, red_card, value, birthday, habit_foot, join_time, contract_time, avatar, flag, create_type, create_time, update_time, injury_history, transfers, season_performace, honors, charaters, read_card, position_performace, single_match_records, vs_teams, jersey_numbers]
# Index: []
#
# [0 rows x 43 columns]

# %%
for i in data.index:
    data['age'].loc[i]=int(data['age'].loc[i])
    print(int(data['age'].loc[i]))
# Out:
# 22
# 29
# 28
# 33
# 33
# 23
# 23
# 25
# 28
# 30
# 31
# 26
# 24
# 30
# 25
# 30
# 30
# 26
# 28
# 26
# 32
# 26
# 21
# 27
# 26
# 26
# 29
# 19
# 26
# 30
# 24
# 28
# 25
# 28
# 26
# 22
# 32
# 21
# 21
# 22
# 33
# 26
# 21
# 25
# 29
# 27
# 27
# 20
# 24
# 30
# 25
# 31
# 25
# 31
# 30
# 31
# 30
# 33
# 34
# 25
# 32
# 26
# 29
# 30
# 30
# 32
# 33
# 31
# 30
# 28
# 27
# 31
# 35
# 40
# 27
# 25
# 31
# 23
# 35
# 26
# 25
# 25
# 24
# 27
# 26
# 33
# 33
# 32
# 23
# 22
# 25
# 34
# 22
# 32
# 36
# 35
# 23
# 25
# 27
# 19
# 30
# 24
# 25
# 27
# 24
# 24
# 32
# 29
# 23
# 29
# 28
# 20
# 33
# 20
# 25
# 22
# 35
# 27
# 25
# 19
# 23
# 27
# 40
# 29
# 22
# 27
# 26
# 18
# 35
# 18
# 23
# 25
# 33
# 29
# 28
# 28
# 31
# 26
# 36
# 30
# 19
# 23
# 23
# 24
# 27
# 28
# 29
# 33
# 37
# 24
# 18
# 24
# 24
# 25
# 29
# 19
# 23
# 22
# 25
# 31
# 20
# 26
# 21
# 26
# 19
# 27
# 32
# 25
# 27
# 26
# 24
# 21
# 25
# 24
# 41
# 20
# 18
# 31
# 21
# 23
# 28
# 31
# 22
# 20
# 30
# 36
# 24
# 20
# 23
# 22
# 22
# 27
# 26
# 20
# 22
# 31
# 24
# 31
# 25
# 27
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17941 entries, 1 to 22473
# Data columns (total 43 columns):
# id                      17941 non-null object
# league_id               17941 non-null object
# league                  8884 non-null object
# team_id                 17941 non-null object
# team_name               17931 non-null object
# national_team_id        17941 non-null object
# national_team           8909 non-null object
# name                    17941 non-null object
# name_en                 17937 non-null object
# short_name              17938 non-null object
# short_en                8714 non-null object
# number                  17941 non-null object
# position                16738 non-null object
# nationality             17938 non-null object
# age                     17941 non-null int64
# height                  17941 non-null object
# weight                  17941 non-null object
# games_played            17941 non-null object
# ...

# %%
data[data['age']==0]
# Out:
#           id league_id league team_id team_name national_team_id  \
# id
# 355      355         0             57   布里斯托尔流浪                0
# 368      368         0             59     什鲁斯伯里                0
# 483      483         0             46       南安联                0
# 496      496         0             46       南安联                0
# 881      881         0             79       约克城                0
# 1564    1564         0            135        卢顿                0
# 1954    1954         0            131    韦康比流浪者                0
# 3032    3032         0            220      米尔沃尔                0
# 3170    3170         0            215       博尔顿                0
# 5913    5913         0            365        韦恩                0
# 7515    7515         0            520      韦尔切利                0
# 9637    9637         0            914      科特布斯                0
# 10086  10086         0    NaN     958       布尔格                0
# ...

# %%
data.groupby('league')['id'].count()
# Out:
# league
#                                          6165
# 3 Liga - Group I                            1
# 3.Liga                                     31
# AFC Asian Cup 2019                          7
# CONCACAF Nations League Qualifikation       1
# LaLiga2                                    41
# Ligue 2                                    26
# Lotto Ekstraklasa                           3
# National League                            38
# Oberliga Schleswig-Holstein                 1
# Parva Liga                                  1
# Torneo Clausura                             1
# Veikkausliiga                               5
# 中超                                         34
# 威超联                                         2
# 德乙                                        138
# 德甲                                        391
# 德甲二线队                                       1
# 德甲二线队东北赛区                                   2
# 德甲二线队西部赛区                                   2
# ...

# %%
data[data['league']=='英超']
# Out:
#           id league_id league team_id team_name national_team_id  \
# id
# 1          1        24     英超     139        曼城                7
# 3          3        24     英超     199       富勒姆                0
# 11        11        24     英超     142       阿森纳                7
# 16        16        24     英超     138       切尔西                7
# 19        19        24     英超     142       阿森纳                0
# 21        21        24     英超     142       阿森纳                7
# 24        24        24     英超       5       利物浦              252
# 25        25        24     英超       5       利物浦              250
# 26        26        24     英超     144      南安普顿                0
# 27        27        24     英超       5       利物浦             3360
# 28        28        24     英超       5       利物浦                0
# 32        32        24     英超       5       利物浦              252
# 33        33        24     英超       5       利物浦                0
# ...

# %%
#data[data['league']=='中超']
data[data['name'].str.contains('C罗') & data['team_name']=='尤文图斯']
# Out:
# /Users/shenxibo/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:1164: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-735e8c453484> in <module>()
#       1 #data[data['league']=='中超']
# ----> 2 data[data['name'].str.contains('C罗') & data['team_name']=='尤文图斯']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1251
#    1252             with np.errstate(all='ignore'):
# -> 1253                 res = na_op(values, other)
#    1254             if is_scalar(res):
#    1255                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
# ...

# %%
data.groupby('position')['id'].count()
# Out:
# position
#        1978
# 中场     5134
# 前锋     3332
# 后卫     4670
# 守门员    1624
# Name: id, dtype: int64

# %%
data[(data['team_name']=='尤文图斯') | (data['team_name']=='利物浦')]
# Out:
#         id league_id league team_id team_name national_team_id national_team  \
# id
# 12      12        48     意甲     567      尤文图斯                7            德国
# 14      14        48     意甲     567      尤文图斯                7            德国
# 24      24        24     英超       5       利物浦              252           英格兰
# 25      25        24     英超       5       利物浦              250            巴西
# 27      27        24     英超       5       利物浦             3360          塞内加尔
# 28      28        24     英超       5       利物浦                0
# 30      30         0              5       利物浦             3357            埃及
# 32      32        24     英超       5       利物浦              252           英格兰
# 33      33        24     英超       5       利物浦                0
# 34      34        24     英超       5       利物浦              255            荷兰
# 35      35        24     英超       5       利物浦                0
# 37      37        24     英超       5       利物浦              252           英格兰
# ...

# %%
data.loc[data['name']=='C罗']['season_performace']
# Out:
# id
# 2289    {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# Name: season_performace, dtype: object

# %%
sgoal=Series(sgoal.values)
sgoal
# Out:
# 0    {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# dtype: object

# %%
sgoal.to_json
# Out:
# <bound method NDFrame.to_json of 0    {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# dtype: object>

# %%
# Out:
# "{'league_type': ['赛事', '球队', '赛季', '出场次数', '进球', '助攻', '红牌', '黄牌', '替补上场', '替补下场', '出场总时间', '黄变红', '场均积分', '乌龙球', '进点球', '进球间隔时间'], 'national_team_type': ['赛事', '球队', '出场次数', '进球', '助攻', '红牌', '黄牌', '替补上场', '替补下场', '出场总时间', '黄变红', '乌龙球', '进点球', '进球间隔时间'], 'league_list': [{'赛事': '欧冠', '球队': '尤文图斯', '赛季': '18/19', '出场次数': '3', '进球': '1', '助攻': '0', '红牌': '1', '黄牌': '0', '替补上场': '0', '替补下场': '0', '出场总时间': '209', '黄变红': '0', '场均积分': '2', '乌龙球': '0', '进点球': '0', '进球间隔时间': '209', '赛事类型': '杯赛'}, {'赛事': '意甲', '球队': '尤文图斯', '赛季': '18/19', '出场次数': '12', '进球': '8', '助攻': '6', '红牌': '0', '黄牌': '0', '替补上场': '0', '替补下场': '0', '出场总时间': '1080', '黄变红': '0', '场均积分': '2.83', '乌龙球': '0', '进点球': '1', '进球间隔时间': '135', '赛事类型': '联赛'}, {'赛事': '超级杯', '球队': '皇家马德里', '赛季': '17/18', '出场次数': '0', '进球': '0', '助攻': '0', '红牌': '0', '黄牌': '0', '替补上场': '0', '替补下场': '0', '出场总时间': '0', '黄变红': '1', '场均积分': '0', '乌龙球': '0', '进点球': '0', '进球间隔时间': '0', '赛事类型': '杯赛'}, {'赛事': '欧超杯', '球队': '皇家马德里', '赛季': '17/18', '出场次数': '1',
# ...

# %%
dg=sgoal.values[0]

# %%
d_total=dg['total']['总计']

# %%
type(d_total['出场次数'])
# Out:
# int

# %%
#直接获取该球员的历史总计记录
data.loc[data['name']=='C罗']['season_performace'][0]['total']['总计']
# Out:
# {'出场次数': 779,
#  '进球': 583,
#  '助攻': 207,
#  '红牌': 7,
#  '黄牌': 93,
#  '替补上场': 80,
#  '替补下场': 130,
#  '出场总时间': 63043,
#  '黄变红': 4,
#  '场均积分': '1.92',
#  '乌龙球': 1,
#  '进点球': 97,
#  '进球间隔时间': '108.13'}

# %%
history=data.loc[data['name']=='C罗']['season_performace'][0]['total']['总计']

# %%
for item in history:
    print(item)
# Out:
# 出场次数
# 进球
# 助攻
# 红牌
# 黄牌
# 替补上场
# 替补下场
# 出场总时间
# 黄变红
# 场均积分
# 乌龙球
# 进点球
# 进球间隔时间

# %%
b=eval(data.loc[10003]['season_performace'])
print(type(b))
print(type(data.loc[10028]['season_performace']))
print(data.loc[10003]['season_performace'])
# Out:
# <class 'dict'>
# <class 'str'>
# ...

# %%
data.index=data.index.astype('int')

# %%
data.loc[5]
# Out:
# id                                                                      5
# league_id                                                               0
# league
# team_id                                                              2570
# team_name                                                           神户胜利船
# national_team_id                                                        0
# national_team
# name                                                                波多尔斯基
# name_en                                                    Lukas Podolski
# short_name                                                          波多尔斯基
# short_en
# number                                                                 10
# position                                                               前锋
# nationality                                                            德国
# age                                                                    33
# ...

# %%
data.loc[21044]
# Out:
# id                                                                  21044
# league_id                                                               0
# league                                                                NaN
# team_id                                                              1964
# team_name                                                            莫雷利亚
# national_team_id                                                        0
# national_team                                                         NaN
# name                                                         胡安·帕布罗·罗德里格斯
# name_en                                              Juan Pablo Rodriguez
# short_name                                                            帕布罗
# short_en                                                              NaN
# number                                                                  8
# position                                                               中场
# ...

# %%
for i in data.index:
    if data.loc[i]['season_performace']!=[]:
        if type(data.loc[i]['season_performace'])==type(''):
            print('第',i,'ge')
            if data.loc[i]['season_performace']!='[]':
                b=eval(data.loc[i]['season_performace'])
                dtest=b['total']['总计']
                for item in dtest:
                    data.loc[:,item][i]=dtest[item]
                    print(i,'    ',item,'   ',data.loc[:,item][i],'  ',dtest[item])
        else:
            dtest=data.loc[i]['season_performace']['total']['总计']
            for item in dtest:
                data.loc[:,item][i]=dtest[item]
                print(i,'    ',item,'   ',data.loc[:,item][i],'  ',dtest[item])
# Out:
# /Users/shenxibo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1      出场次数     240    240
# 1      进球     59    59
# 1      助攻     60    60
# 1      红牌     0    0
# 1      黄牌     23    23
# 1      替补上场     68    68
# 1      替补下场     83    83
# 1      出场总时间     15554    15554
# 1      黄变红     0    0
# 1      场均积分     1.91    1.91
# 1      乌龙球     0    0
# 1      进点球     0    0
# 1      进球间隔时间     263.62    263.62
# 2      出场次数     548    548
# 2      进球     221    221
# 2      助攻     156    156
# 2      红牌     0    0
# 2      黄牌     31    31
# 2      替补上场     75    75
# 2      替补下场     175    175
# 2      出场总时间     41374    41374
# 2      黄变红     1    1
# 2      场均积分     2.25    2.25
# 2      乌龙球     0    0
# 2      进点球     25    25
# ...

# %%
#data.loc[10014]['season_performace']!=[]
data.loc[:,'season_performace'][5]=[]
data.loc[:,'season_performace']
# Out:
# /Users/shenxibo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# id
# 1        {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 2        {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 3        {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 4        {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 5                                                       []
# 7        {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 8        {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 9        {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 10       {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 11       {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# 12       {'league_type': ['赛事', '球队', '赛季', '出场次数', '进球...
# ...

# %%
data.head()
# Out:
#    id league_id league team_id team_name national_team_id national_team  \
# id
# 1   1        24     英超     139        曼城                7            德国
# 2   2        59     德甲     222     拜仁慕尼黑                7            德国
# 3   3        24     英超     199       富勒姆                0
# 4   4        59     德甲     335      斯图加特                7            德国
# 5   5         0           2570     神户胜利船                0
#
#       name         name_en short_name  ...  替补上场 替补下场  出场总时间 黄变红  场均积分 乌龙球  \
# id                                     ...
# 1       萨内      Leroy Sané         萨内  ...    81  143  43710   3  1.60   0
# 2   托马斯-穆勒   Thomas Müller         穆勒  ...    81  143  43710   3  1.60   0
# 3      许尔勒  Andre Schurrle        许尔勒  ...    81  143  43710   3  1.60   0
# 4      戈麦斯     Mario Gomez        戈麦斯  ...    81  143  43710   3  1.60   0
# 5    波多尔斯基  Lukas Podolski      波多尔斯基  ...    81  143  43710   3  1.60   0
#
#    进点球  进球间隔时间 总丢球数 未丢球场次
# id
# 1    1  672.46   61    18
# ...

# %%
data.describe()
# Out:
#                 age          出场次数            进球            助攻            红牌  \
# count  17941.000000  17941.000000  17941.000000  17941.000000  17941.000000
# mean      26.490162    507.331029     57.015272     49.376177      3.246140
# std        4.930529    157.060927     26.142573     20.281533      1.498737
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       23.000000    584.000000     65.000000     58.000000      4.000000
# 50%       26.000000    584.000000     65.000000     58.000000      4.000000
# 75%       30.000000    584.000000     65.000000     58.000000      4.000000
# max       46.000000    970.000000    593.000000    239.000000     11.000000
#
#                  黄牌          替补上场          替补下场         出场总时间           黄变红  \
# count  17941.000000  17941.000000  17941.000000  17941.000000  17941.000000
# mean     123.838749     71.758988    120.861602  37995.412853      2.492280
# ...

# %%
# important
data.to_csv('/Users/shenxibo/study/python/data tables/zhibo8 players/zhiboplayer_all_2.csv',index=False,encoding='utf-8')

# %%
# about the history
data_history=data['出场次数']

# %%
data['season_performace'][5]=='[]'
# Out:
# False

# %%
data_history=data[data['season_performace']!='[]']

# %%
data_history.sort_values(by='出场次数',ascending=False)[:10]
# Out:
#           id league_id league team_id team_name national_team_id  \
# id
# 3735    3735         0            329   莫斯科中央陆军              247
# 1706    1706         0           2358     洛杉矶银河             2063
# 7787    7787        80     法甲     931    巴黎圣日耳曼                0
# 3244    3244        80     法甲     931    巴黎圣日耳曼              229
# 3671    3671        48     意甲     567      尤文图斯              249
# 13558  13558         0    NaN    1273    莫斯科火车头                0
# 3712    3712         0           1460       巴塞尔              257
# 3633    3633         0           1557       波尔图                0
# 3686    3686        24     英超     200        狼队              256
# 8322    8322        59     德甲     585   门兴格拉德巴赫             3258
#
#       national_team    name             name_en short_name  ...  替补上场 替补下场  \
# id                                                          ...
# 3735            俄罗斯   阿金费耶夫       Igor Akinfeev      阿金费耶夫  ...     6    5
# ...

# %%
data['season_performace']!='[]'
# Out:
# id
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
# 30        True
# 32        True
#          ...
# 22430    False
# 22431    False
# 22432    False
# 22433    False
# 22434    False
# 22435    False
# 22436    False
# 22437    False
# 22438    False
# 22439    False
# 22440    False
# 22441    False
# 22442    False
# 22443    False
# 22444    False
# 22445    False
# 22446    False
# 22447    False
# 22448    False
# 22449    False
# 22450    False
# 22451    False
# 22452    False
# 22453    False
# 22454    False
# 22455    False
# 22456    False
# ...

# %%
dcr7=data.loc[data['name']=='C罗']['honors'].values

# %%
dcr7
# Out:
# array([{'国际足联金球奖': {'honor': '国际足联金球奖', 'logo': 'http://db.qiumibao.com/avatar/playerhonor/3/dc58004d4b202e0fae4b180dd6757785.png', 'times': 5, 'sub': [{'season': '2017', 'level': '2', 'match_id': '0', 'match_name': '皇家马德里'}, {'season': '2016', 'level': '2', 'match_id': '0', 'match_name': '皇家马德里'}, {'season': '2014', 'level': '2', 'match_id': '0', 'match_name': '皇家马德里'}, {'season': '2013', 'level': '2', 'match_id': '0', 'match_name': '皇家马德里'}, {'season': '2008', 'level': '2', 'match_id': '0', 'match_name': '曼联'}]}, '欧洲最佳球员': {'honor': '欧洲最佳球员', 'logo': 'http://db.qiumibao.com/avatar/playerhonor/3/1239a11db0f4fa99b53c4fac7df06c1f.png', 'times': 5, 'sub': [{'season': '2017', 'level': '2', 'match_id': '0', 'match_name': '皇家马德里'}, {'season': '2016', 'level': '2', 'match_id': '0', 'match_name': '皇家马德里'}, {'season': '2014', 'level': '2', 'match_id': '0', 'match_name': '皇家马德里'}, {'season': '2008', 'level': '2', 'match_id': '0', 'match_name': '曼联'}, {'season': '2013', 'level': '2', 'match_id
# ...

# %%
scr7=Series(dcr7)
scr7
# Out:
# 0    {'国际足联金球奖': {'honor': '国际足联金球奖', 'logo': 'http...
# dtype: object

# %%
scr7['国际足联金球奖']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-516-23eb2d7e6c57> in <module>()
# ----> 1 scr7['国际足联金球奖']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
# ...

# %%
import requests
import numpy as np
from pandas import DataFrame,Series
import json


#20190522，分布运行，获取数据，并将数据存储在dataframe表中，51009-99999
url='https://db.qiumibao.com/f/index/player?pid='
r=requests.get(url+'1')
s=Series(r.json())
#data = DataFrame(columns=s.index)
for i in range(58236,99999):
    r=requests.get(url+str(i+1))
    if r.json():
        sp=Series(r.json())
        sp['read_card']=''
        data.loc[i]=sp.values
        print(i,'  ',data.loc[i]['name'])
# Out:
# 58236    卢卡-齐达内
# 58237    Javier Belman
# 58238    Moha Ramos
# 58239    哈维-桑切斯
# 58240    Manu Hernando
# 58241    ?lex Martín
# 58242    Julio Buffarini
# 58243    Gorka Zabarte
# 58244    阿德里安-德拉富恩特
# 58245    弗兰-加西亚
# 58246    Sergio López
# 58247    Dani Fernández
# 58248    哈乌梅-加拉乌
# 58249    Ayoub Abou
# 58250    海梅·塞奥亚内
# 58251    阿尔瓦罗-费达尔戈
# 58252    Martin Calderón
# 58253    Augusto Galvan
# 58254    Jorge De Frutos
# 58255    弗兰楚
# 58256    Alberto Fernández
# 58257    克里斯托
# 58258    Dani Gómez
# 58259    Jan Glinker
# 58260    Tino Berbig
# 58261    Ruben Aulig
# 58262    Florian Esdorf
# 58263    Jerome Propheter
# 58264    Felix Müller
# 58265    Maurice Pluntke
# 58266    Christoph G?bel
# 58267    Mounir Chaftar
# 58268    Tim H?u?ler
# 58269    Sebastian Heidinger
# 58270    Vladimir Kovac
# 58271    Tobias Becker
# 58272    Matthias Pe?olat
# 58273    Robin Flu?
# 58274    Mateo Andacic
# 58275    Cihan Ucar
# 58276    Benjamin Kauffmann
# 58277    Stepan Kores
# ...

# %%
data.to_csv('0522data/data51009T99999.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10994 entries, 51009 to 64016
# Data columns (total 47 columns):
# id                      10994 non-null object
# league_id               10994 non-null object
# league                  10994 non-null object
# team_id                 10994 non-null object
# team_name               10994 non-null object
# national_team_id        10994 non-null object
# national_team           10994 non-null object
# name                    10994 non-null object
# name_en                 10994 non-null object
# short_name              10994 non-null object
# short_en                10994 non-null object
# number                  10994 non-null object
# position                10994 non-null object
# nationality             10994 non-null object
# age                     10994 non-null object
# height                  10994 non-null object
# weight                  10994 non-null object
# retired                 10994 non-null object
# ...
